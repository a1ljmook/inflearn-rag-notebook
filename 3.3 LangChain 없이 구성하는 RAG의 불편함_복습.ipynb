# %% [markdown]
# # 1. 패키지 설치

# %%
# %pip install python-docx python-dotenv tiktoken chromadb openai

# %% [markdown]
# # 2. Knowledge Base 구성을 위한 데이터 생성

# %%
docs =   "./documents/tax_with_markdown.docx"
full_text = ""

print(full_text)

# %%
def split_text(  ):
    encoder =   "gpt-4o-mini"
    total_encoding = 
    total_encoding_count = 
    text_list = []
    for i 
        chunk = 
        decoded = 

    return

chunk_size = 1500
chunk_list = 
print(len(chunk_list))
chunk_list

# %%
print(chunk_list[0])

# %%
chroma_client = 
chroma_collection_name = "chroma-tax-collection"
chroma_tax_collection = 
chroma_tax_collection

# %%
from dotenv import load_dotenv
import os


load_dotenv()
openai_api_key = os.environ["OPENAI_API_KEY"]

openai_collection_name = "openai-tax-collection"
openai_embedding =   "text-embedding-3-large"
openai_tax_collection =

# %%
ids = []
for idx 

openai_tax_collection

# %% [markdown]
# # 3. 답변 생성을 위한 Retrieval

# %%
query = "연봉 1억원인 직장인의 소득세는 얼마인가요?"
retrieved_doc = 
retrieved_doc

# %%
retrieved_doc["documents"][0]

# %% [markdown]
# # 4. Augmentation을 위한 Prompt 활용 및 답변 생성

# %%
 
client = 
context = 
response = 

        "당신은 한국의 소득세 전문가 입니다. 아래 내용을 참고해서 사용자의 질문에 답변해주세요""


response

# %%
print
