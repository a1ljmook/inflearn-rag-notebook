# %% [markdown]
# # 1. 패키지 설치

# %%
# %pip install langchain langchain-core langchain-community langchain-text-splitters langchain-openai langchain-pinecone docx2txt

# %% [markdown]
# # 2. Knowledge Base 구성을 위한 데이터 생성

# %%
doc_loader =   "./documents/tax_with_markdown.docx"
text_splitter =   (chunk_size=1500, chunk_overlap=200)
doc_list = 
len(doc_list)

# %%
print(doc_list[0].page_content)

# %%
from dotenv import load_dotenv

load_dotenv(dotenv_path="../_elice_llm/.env")
# Out:
# True

# %%
embedding = 
# vector_db = 
vector_db =

# %%
index_name = "pinecone-tax-index"
pinecone_api_key = 
pc = 
pinecone_db =

# %% [markdown]
# # 3. 답변 생성을 위한 Retrieval

# %%
query = '연봉 1억원인 거주자의 종합소득세는?'

# %%
retriever = 
retrieved_docs = 
retrieved_docs

# %% [markdown]
# # 4. Augmentation을 위한 Prompt 활용

# %%
llm_openai = 
llm_ollama =

# %%
prompt =

# %% [markdown]
# # 5. 답변 생성

# %%
# from langchain.chains import RetrievalQA

# qa_chain = RetrievalQA.from_chain_type(
#     llm, 
#     retriever=retriever,
#     chain_type_kwargs={"prompt": prompt}
# )

# %%
# # LangChain 권장사항에 따라 강의 코드와 다르게 `.invoke()`를 사용합니다
# ai_message = qa_chain.invoke({"query": query})

# ai_message
