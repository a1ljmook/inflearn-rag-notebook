# %% [markdown]
# # 1. 패키지 설치

# %%
# %pip install -q python-dotenv langchain-community

# %% [markdown]
# # 2. LLM 답변 생성
#
# - `ChatOllama` 를 활용한 LLM 답변 생성
# - 터미널에서 `ollama pull gemma2` 와 같이 원하는 모델을 가져와야 실행 가능

# %%
from langchain_ollama import ChatOllama

question = "인프런에 어떤 강의가 있나요?"
llm_ollama = ChatOllama(model="mistral")
llm_ollama_response = llm_ollama.invoke(question)
print(llm_ollama_response.content)
# Out:
#  인프런(Inflearn)에는 다양한 교육 컨텐츠가 제공됩니다. 여기서 일부 주목할 수 있는 강의들입니다:
#
# 1. Python 프로그래밍  zero! (Python으로 시작하기)
# 2. JavaScript ES6 정복 (ES6 이후 추가된 새로운 기능과 자바스크립트의 최신 개발)
# 3. 웹 프론트엔드 프레임워크  Angular2 (Angular 2를 이용한 웹 애플리케이션 만들기)
# 4. AWS Certified Solutions Architect - Associate 전체 강의 (AWS 시스템 아키텍처를 설계하는 방법 학습)
# 5. 데이터베이스 최적화 - MySQL & Oracle 최적화 (MySQL과 Oracle을 사용한 데이터베이스 최적화)
# 6. Swift 프로그래밍  zero! (iOS 앱 만들기)
# 7. Spring Framework 2편 - Web MVC, DB Access & AOP (Spring Framework를 이용한 백엔드 애플리케이션 개발)
# 8. Java 11로 최신 자바 프로그래밍 기초부터 (최신 Java 11과 JDK 11에서의 새로운 기능 및 사용법)
# 9. 안드로이드 앱 개발 제대로 배우기 (Android Studio와 Kotlin으로 안드로이드 앱 만들기)
# 10. React 프로그래밍  zero! (React를 이용한 웹 애플리케이션 구현)

# %%
from langchain_community.chat_models import ChatOllama

llm_ollama_2 = ChatOllama(model="mistral")
llm_ollama_response_2 = llm_ollama_2.invoke(question)
print(llm_ollama_response_2.content)
# Out:
# C:\Users\limjangmook\AppData\Local\Temp\ipykernel_25008\291580708.py:3: LangChainDeprecationWarning: The class `ChatOllama` was deprecated in LangChain 0.3.1 and will be removed in 1.0.0. An updated version of the class exists in the `langchain-ollama package and should be used instead. To use it run `pip install -U `langchain-ollama` and import as `from `langchain_ollama import ChatOllama``.
#   llm_ollama_2 = ChatOllama(model="mistral")
#  Inflearn에는 다양한 강의가 존재합니다. 전문분야, 취업준비, IT 개발, 디자인, 영어 습관 등 다양한 주제의 강의를 찾을 수 있습니다.
#
# 예를 들면:
# 1. 프로그래밍 언어: Python, Java, JavaScript 등
# 2. 웹 및 모바일 개발: React, Angular, Swift, Android 등
# 3. 데이터 분석 및 기계학습: Excel, SQL, TensorFlow, Keras 등
# 4. 디자인: Adobe Illustrator, Photoshop, After Effects 등
# 5. 취업준비: 인턴십 구하는 방법, 면접 공부 및 스펙트럼 등
# 6. 생활 및 사회적 정보: 영어 습관, 피нан스, 행정법 등
#
#  Inflearn의 강의는 전문가들이 직접 만든 수업으로, 자세한 내용과 실전 경험을 담고 있습니다.
