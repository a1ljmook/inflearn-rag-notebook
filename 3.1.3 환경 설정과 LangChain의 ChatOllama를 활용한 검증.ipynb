# %% [markdown]
# # 1. 패키지 설치

# %%
# %pip install -q python-dotenv langchain-community

# %% [markdown]
# # 2. LLM 답변 생성
#
# - `ChatOllama` 를 활용한 LLM 답변 생성
# - 터미널에서 `ollama pull gemma2` 와 같이 원하는 모델을 가져와야 실행 가능

# %%
from langchain_ollama import ChatOllama

question = "인프런에 어떤 강의가 있나요?"
llm_ollama = ChatOllama(model="mistral")
llm_ollama_response = llm_ollama.invoke(question)
print(llm_ollama_response.content)
# Out:
#  Inflearn에는 다양한 학습 컨텐츠들이 제공되고 있으며, IT 분야에서도 유명하다. 여기에는 프로그래밍 언어, 데이터 분석, 디자인, AI/ML, 웹 및 모바일 개발 등 다양한 주제가 있습니다. 예를 들어, Python, Java, JavaScript, Swift, C++ 등의 프로그래밍 언어에 대한 강좌도 존재하며, TensorFlow, PyTorch, scikit-learn, Keras와 같은 AI/ML 라이브러리에 대한 학습 내용도 제공됩니다.
#
# 다음은 Inflearn에서 신규 강의가 추천되는 몇 가지 주제입니다.
#
# 1. 파이썬(Python) for Data Science and Machine Learning Bootcamp (Zero to Mastery)
# 2. Web Development Bootcamp (Academind)
# 3. Deep Learning Specialization (Andrew Ng)
# 4. JavaScript from Scratch: Understand the Core Fundamentals (Academind)
# 5. 리액트(React) Native 프로젝트 개발 입문 (이펙티브코딩, 김영한님)
# 6. 모바일 웹 개발 입문 (이펙티브코딩, 김영한님)
# 7. 이미지 처리와 대규모 데이터 분석(Image Processing and Large Data Analysis) (인재투자, 전기원님)
# 8. 서버사이드 웹 개발 입문 (Node.js) (이펙티브코딩, 김영한님)
# 9. TensorFlow 2.0 완전 동영상 강좌 (인재투자, 전기원님)
# 10. Swift UI와 Combine 입문 (이펙티브코딩, 김영한님)

# %%
from langchain_community.chat_models import ChatOllama

llm_ollama_2 = ChatOllama(model="mistral")
llm_ollama_response_2 = llm_ollama_2.invoke(question)
print(llm_ollama_response_2.content)
# Out:
# C:\Users\a1ljm\AppData\Local\Temp\ipykernel_17568\291580708.py:3: LangChainDeprecationWarning: The class `ChatOllama` was deprecated in LangChain 0.3.1 and will be removed in 1.0.0. An updated version of the class exists in the `langchain-ollama package and should be used instead. To use it run `pip install -U `langchain-ollama` and import as `from `langchain_ollama import ChatOllama``.
#   llm_ollama_2 = ChatOllama(model="mistral")
#  인프런(Inflearn)에는 다양한 분야의 온라인 교육 강의를 제공합니다. 예를 들어, IT 분야에서는 Python, Java, 웹 개발, 데이터 분석, 머신 러닝 등의 관련 강의가 있습니다. 또한, 디자인, 생활, 경영 등 다양한 분야에서도 강의를 제공합니다.
#
# 인프런에서 강의를 찾고 싶으신 경우, 아래와 같은 방법으로 검색하실 수 있습니다.
#
# 1. 인프런 홈페이지(https://www.inflearn.com/)에 접속합니다.
# 2. 분야나 키워드를 입력하여 검색합니다(예: "Python", "데이터 분석", "디자인").
# 3. 원하신 강의를 선택하고, 수강료나 설명서를 확인하시면 됩니다!
#
# 추천 강의로는 '모두의 코딩 파이썬'과 '김영한의 웹 개발자 성격 유형'이 있습니다. 이러한 강의를 수강하시면, 특정 분야나 관심사에 적합한 교육을 받고 실력을 향상할 수 있을 것입니다!
