# %% [markdown]
# # 1. 패키지 설치

# %%
# %pip install -q python-dotenv langchain-openai
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # 2. 환경변수 불러오기
#
# - `.env` 파일에 `OPENAI_API_KEY` 등록

# %%
from dotenv import load_dotenv
import os

load_dotenv()
# os.environ["OPENAI_API_KEY"]
# Out:
# True

# %% [markdown]
# # 3. LLM 답변 생성
#
# - OpenAI 대시보드에서 발급받은 API Key를 `OPENAI_API_KEY`라고 저장하면 별도의 설정 없이 `ChatOpenAI`를 사용할 수 있음

# %%
from langchain_openai import ChatOpenAI

llm_openai = ChatOpenAI(model="gpt-4.1-mini")

# %%
question = "인프런에 어떤 강의가 있나요?"
llm_openai_message = llm_openai.invoke(question)

# %%
print(llm_openai_message.content)
# Out:
# 인프런(Inflearn)은 다양한 분야의 온라인 강의를 제공하는 플랫폼으로, 프로그래밍, 데이터 사이언스, 디자인, 마케팅 등 여러 주제의 강의를 찾을 수 있습니다. 대표적인 강의 분야와 예시는 다음과 같습니다:
#
# 1. **프로그래밍**
#    - 자바스크립트, 파이썬, 자바, C++, C# 등 주요 언어 강의
#    - 웹 개발 (React, Vue, Angular, Django 등)
#    - 모바일 앱 개발 (안드로이드, iOS)
#    - 알고리즘 및 자료구조
#
# 2. **데이터 사이언스 & 인공지능**
#    - 데이터 분석, 머신러닝, 딥러닝 입문부터 심화 과정
#    - 텐서플로우, 파이토치 등 프레임워크 사용법
#
# 3. **게임 개발**
#    - 유니티, 언리얼 엔진 강의
#    - 게임 그래픽과 기획
#
# 4. **디자인**
#    - UX/UI 디자인, 그래픽 디자인, 포토샵, 일러스트레이터
#
# 5. **업무 스킬 & 생산성**
#    - 엑셀, 파워포인트, 비즈니스 커뮤니케이션
#    - 프로젝트 관리, 자기계발
#
# 6. **마케팅 & 창업**
#    - 디지털 마케팅, SEO, SNS 마케팅
#    - 스타트업 창업, 비즈니스 전략
#
# 인프런 홈페이지에 접속해서 관심 분야를 검색하거나, 인기 강의와 추천 강의를 확인하시면 더욱 상세한 정보를 얻으실 수 있습니다. 원하는 주제를 알려주시면 구체적으로 추천 강의를 안내해 드릴 수도 있습니다!

# %%
from langchain_ollama import ChatOllama

question = "인프런에 어떤 강의가 있나요?"
llm_ollama = ChatOllama(model="qwen2.5")
llm_ollama_message = llm_ollama.invoke(question)
print(llm_ollama_message.content)
# Out:
# 인프런은 다양한 분야의 온라인 교육 플랫폼입니다. 특정 강의 내용을 알기 위해서는 인프런 웹사이트 또는 앱을 방문하여 검색을 해보시는 것이 가장 정확한 방법일 것입니다.
#
# 그럼에도 불구하고, 인프런에는 다음과 같은 주요 카테고리의 강의들이 일반적으로 제공되고 있습니다:
#
# 1. 프로그래밍과 개발
# 2. 디자인 및 웹 개발
# 3. 영어와 언어 학습
# 4. 데이터 과학 및 분석
# 5. 비즈니스 및 마케팅
# 6. 인문과학
# 7. 사진 및 비디오 편집
#
# 특정 주제에 대해 더 자세한 정보를 원하신다면, 인프런 웹사이트나 앱에서 해당 카테고리를 찾아보시거나, 직접 강의 제목을 검색해보시는 것이 좋습니다.
