# %% [markdown]
# # 1. 패키지 설치

# %%
# %pip install -q python-dotenv langchain-openai
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # 2. 환경변수 불러오기
#
# - `.env` 파일에 `OPENAI_API_KEY` 등록

# %%
from dotenv import load_dotenv
import os

load_dotenv()
# os.environ["OPENAI_API_KEY"]
# Out:
# True

# %% [markdown]
# # 3. LLM 답변 생성
#
# - OpenAI 대시보드에서 발급받은 API Key를 `OPENAI_API_KEY`라고 저장하면 별도의 설정 없이 `ChatOpenAI`를 사용할 수 있음

# %%
from langchain_openai import ChatOpenAI

llm_openai = ChatOpenAI(model="gpt-4.1-mini")

# %%
question = "인프런에 어떤 강의가 있나요?"
llm_openai_message = llm_openai.invoke(question)

# %%
print(llm_openai_message.content)
# Out:
# 인프런(Inflearn)은 한국의 온라인 교육 플랫폼으로, 다양한 분야의 강의를 제공합니다. 주로 IT, 프로그래밍, 데이터 사이언스, 디자인, 마케팅 등 실무 중심의 강의가 많습니다.
#
# 인프런에서 제공하는 대표적인 강의 유형은 다음과 같습니다:
# - 프로그래밍 언어: Python, Java, JavaScript, C++, C#, 등
# - 웹 개발: HTML, CSS, React, Vue.js, Node.js, Django 등
# - 데이터 분석 및 데이터 사이언스: Pandas, NumPy, 머신러닝, 딥러닝, TensorFlow, PyTorch 등
# - 모바일 개발: Android, iOS, Flutter 등
# - 클라우드 및 DevOps: AWS, Azure, Docker, Kubernetes 등
# - 디자인: UI/UX, 포토샵, 일러스트레이터, Figma 등
# - 마케팅 및 비즈니스: 디지털 마케팅, 스타트업, 기획 등
#
# 구체적으로 어떤 강의를 찾으시는지 알려주시면 더 자세한 추천을 드릴 수 있습니다! 아니면 인프런 웹사이트에서 관심 분야를 직접 검색해보시는 것도 좋습니다.

# %%
from langchain_ollama import ChatOllama

question = "인프런에 어떤 강의가 있나요?"
llm_ollama = ChatOllama(model="qwen2.5")
llm_ollama_message = llm_ollama.invoke(question)
print(llm_ollama_message.content)
# Out:
# 인프런은 다양한 주제와 분야의 온라인 교육 플랫폼입니다. 특정 강좌에 대한 자세한 정보를 제공하기 위해서는 인프런 웹사이트 또는 앱을 직접 방문하여 확인하시는 것이 가장 정확합니다. 그럼에도 불구하고, 일반적으로 인프런에는 아래와 같은 주제의 강좌들이 공개되어 있습니다:
#
# 1. **프로그래밍과 웹개발**: Python, Java, JavaScript, React, Vue.js 등의 언어와 프레임워크를 다루는 강좌들.
# 2. **데이터 분석 및 기계 학습**: Pandas, NumPy, TensorFlow, PyTorch 등을 이용한 데이터 처리 및 머신러닝 관련 강좌들이 있습니다.
# 3. **디자인**: UI/UX 디자인, 캐리커처, 그래픽 디자인 등 다양한 분야의 디자인 강좌들이 있습니다.
# 4. **마케팅 및 영업**: SEO, SNS 마케팅, 판매 기법 등에 대한 교육이 제공됩니다.
# 5. **글쓰기와 편집**: 플로우, 글쓰기 트렌드, 편집 기술 등의 코스들이 있습니다.
# 6. **가공艺术与设计**: 设计思维、产品设计、UI/UX 设计等。
#
# 请注意，这些类别是基于常见的课程主题进行的概括，并不代表实际内容或最新信息。为了获取最准确和最新的课程信息，请直接访问官网或应用查看。如果您对某个具体领域的课程有兴趣，也可以告诉我，我可以给出更具体的建议！
